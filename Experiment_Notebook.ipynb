# %% [markdown]
# # **starting with the *experiments***

# %% [markdown]
# ###installation of the necessary libraries

# %%
# !pip install langchain_core langgraph  langchain  langchain_groq langchain_community pydantic

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import HumanMessage,AIMessage, BaseMessage
from langchain_groq import ChatGroq
from langchain_community.document_loaders import CSVLoader
from pydantic import BaseModel
from typing_extensions import TypedDict
from langgraph.graph import StateGraph
from langgraph.graph.message import add_messages
from langgraph.graph import START ,END
from langgraph.checkpoint.memory import InMemorySaver
from langgraph.prebuilt import ToolNode
from langchain_core.tools import tool
from langchain.tools import tool_node

# %%
data=pd.read_csv("diabetes.csv")

# %%
"""
Node 1: The Data Profiler (The "Eyes")

Action: Reads the CSV (using Pandas).

Efficiency: It doesn't send the whole CSV to the LLM. It sends: df.dtypes, df.isnull().sum(), and df.describe().
          Goal: Provide the LLM with enough context to understand the shape of the data.


Node 2: The Visualization Strategist (The "Architect")
Action: This node doesn't write code yet. It reasons.

      Logic: "I see 'Date' and 'Revenue'. I should create a time-series line chart with a rolling average to identify the trend."

Output: A natural language plan for the next node.


Node 3: The Coder & Executor (The "Hands")

    Action: Uses the plan to write Seaborn/Matplotlib code.

Robustness: It attempts to execute the code.

If success: Move to the next node.

If failure: It catches the Exception, adds it to error_log, and loops back to try again.


Node 4: The Insight Reporter (The "Analyst")

       Action: This is the most complex prompt. It looks at the Statistics + the Chart Strategy + the User Question.

Output: A professional Markdown report including:

     The "What": Summary of data.

     The "Why": Why the graph shows a dip or a spike.

     The "So What": Actionable business insights.
"""
# Out:
# '\nNode 1: The Data Profiler (The "Eyes")\n\nAction: Reads the CSV (using Pandas).\n\nEfficiency: It doesn\'t send the whole CSV to the LLM. It sends: df.dtypes, df.isnull().sum(), and df.describe().  \n          Goal: Provide the LLM with enough context to understand the shape of the data.\n\n\nNode 2: The Visualization Strategist (The "Architect")\nAction: This node doesn\'t write code yet. It reasons.\n \n      Logic: "I see \'Date\' and \'Revenue\'. I should create a time-series line chart with a rolling average to identify the trend."\n\nOutput: A natural language plan for the next node.\n\n\nNode 3: The Coder & Executor (The "Hands")\n\n    Action: Uses the plan to write Seaborn/Matplotlib code.\n\nRobustness: It attempts to execute the code.\n\nIf success: Move to the next node.\n  \nIf failure: It catches the Exception, adds it to error_log, and loops back to try again.\n\n\nNode 4: The Insight Reporter (The "Analyst")\n\n       Action: This is the most complex prompt. It looks at the Statistics + the Chart Strategy + the User Question.\n\nOutput: A professional Markdown report including:\n\n     The "What": Summary of data.\n\n     The "Why": Why the graph shows a dip or a spike.\n\n     The "So What": Actionable business insights.\n'

# %%
from typing import TypedDict, List, Annotated
import pandas as pd
from langgraph.graph.message import add_messages

class AgentState(TypedDict):
    messages: Annotated[list, add_messages]
    csv_path: str
    data_summary: str      # Text summary of the data
    columns: List[str]     # List of column names
    viz_plan: str          # The strategy for the chart
    viz_code: str          # The generated python code
    viz_path: str          # Where the image is saved
    error_log: str         # Any errors from the code execution
    final_report: str      # The final markdown analysis

# %%
def profiler_node(state: AgentState):

    df = pd.read_csv(state['csv_path'])

    summary = f"""
    Dataset Shape: {df.shape}
    Columns & Types: {df.dtypes.to_dict()}
    Missing Values: {df.isnull().sum().to_dict()}
    Statistical Summary:
    {df.describe().to_string()}
    """
    return {
        "data_summary": summary,
        "columns": list(df.columns)
    }

# %%
llm=ChatGroq(model="openai/gpt-oss-120b" ,api_key=GROQ_API_KEY)

# %%
def strategist_node(state: AgentState):
    # Prompt the LLM
    prompt = f"""
    You are a Data Strategy Expert. Based on this data summary:
    {state['data_summary']}

    Identify the most important business trend or correlation.
    Describe a Seaborn visualization that would reveal this insight.
    Output only the plan in one paragraph.
    """
    # Replace with your actual LLM call logic
    response = llm.invoke(prompt)
    return {"viz_plan": response.content}

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def coder_executor_node(state: AgentState):
    # Prompt LLM to write code based on state['viz_plan']
    code_prompt = f"""
    Write Python code using Seaborn to create the following chart: {state['viz_plan']}
    - The dataframe is already loaded as 'df'.
    - Use sns.set_theme().
    - Save the plot to 'static/analysis_plot.png' using plt.savefig().
    - Do not use plt.show().
    """
    generated_code = llm.invoke(code_prompt).content

    df = pd.read_csv(state['csv_path'])
    local_vars = {"df": df, "plt": plt, "sns": sns}

    try:
        exec(generated_code, {}, local_vars)
        return {"viz_code": generated_code, "viz_path": "static/analysis_plot.png", "error_log": ""}
    except Exception as e:
        return {"error_log": str(e)}

# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from typing import TypedDict, List, Annotated, Dict
from langgraph.graph import StateGraph, END
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage


class AgentState(TypedDict):
    csv_path: str
    data_summary: str
    analysis_plan: List[Dict[str, str]]
    viz_results: List[Dict[str, str]]
    viz_code: str
    final_report: str
    error_log: str
    retry_count: int


def profiler_node(state: AgentState):
    """Profiles the data with enough detail for deep visualization strategy."""
    df = pd.read_csv(state['csv_path'])
    summary = f"""
    SHAPE: {df.shape}
    COLUMNS: {list(df.columns)}
    NUMERIC COLS: {list(df.select_dtypes(include=['number']).columns)}
    CATEGORICAL COLS: {list(df.select_dtypes(include=['object']).columns)}
    STATS: \n{df.describe().to_string()}
    """
    return {
        "data_summary": summary,
        "analysis_plan": [],
        "viz_results": [],
        "viz_code": "",
        "final_report": "",
        "error_log": "",
        "retry_count": 0
    }

def strategist_node(state: AgentState):
    """The 'Brain' - Demands a full suite of EDA plots."""
    llm = ChatGroq(model="openai/gpt-oss-120b", api_key=GROQ_API_KEY)

    system_msg = """You are a Lead Data Analyst. Your goal is to replace a human analyst.
    Plan 7-10 distinct visualizations to explore this dataset fully.
    You MUST include at least one of each:
    - Distribution (Histogram/KDE)
    - Correlation (Scatter/Relational/Heatmap)
    - Comparison (Bar/Count)
    - Composition (Boxplot/Violin)

    Output ONLY a JSON list: [{"title": "...", "plot_type": "...", "columns": [], "insight_goal": "..."}]"""

    response = llm.invoke([SystemMessage(content=system_msg), HumanMessage(content=state['data_summary'])])
    clean_json = response.content.replace("```json", "").replace("```", "").strip()

    return {"analysis_plan": json.loads(clean_json)}

def coder_node(state: AgentState):
    """The 'Programmer' - Writes the multi-plot Seaborn script."""
    llm = ChatGroq(model="openai/gpt-oss-120b", api_key=GROQ_API_KEY)

    tasks = json.dumps(state['analysis_plan'])
    error_context = f"\nFIX PREVIOUS ERROR: {state['error_log']}" if state['error_log'] else ""

    system_msg = f"""Write Python code using Seaborn/Matplotlib.
    - Dataframe is 'df'.
    - Generate {len(state['analysis_plan'])} separate plots.
    - Save each as 'static/plot_n.png'.
    - Use plt.close('all') after each save.
    - Tasks: {tasks}
    {error_context}
    OUTPUT ONLY RAW PYTHON CODE."""

    response = llm.invoke([SystemMessage(content=system_msg), HumanMessage(content="Write the EDA script.")])

    return {"viz_code": response.content.replace("```python", "").replace("```", "").strip()}


def executor_node(state: AgentState):
    """The 'Engine' - Runs the code and prepares the visual evidence."""
    df = pd.read_csv(state['csv_path'])
    os.makedirs("static", exist_ok=True)
    local_vars = {"df": df, "plt": plt, "sns": sns, "pd": pd}

    try:
        plt.close('all')
        exec(state['viz_code'], {}, local_vars)

        results = []
        for i, task in enumerate(state['analysis_plan']):
            path = f"static/plot_{i}.png"
            if os.path.exists(path):
                # FIXED: Logic to use task goal
                results.append({"title": task['title'], "path": path, "goal": task.get('insight_goal', '')})

        return {"viz_results": results, "error_log": "", "retry_count": state['retry_count'] + 1}
    except Exception as e:
        return {"error_log": str(e), "retry_count": state['retry_count'] + 1}

def analyst_node(state: AgentState):
    """The 'Reporter' - The human-replacement storyteller."""
    llm = ChatGroq(model="openai/gpt-oss-120b", api_key=GROQ_API_KEY)

    viz_meta = json.dumps(state['viz_results'])
    system_msg = """You are a World-Class Data Journalist.
    You have a full suite of visualizations. For EVERY plot provided:
    1. Give it a clear Header.
    2. Explain the visual evidence.
    3. Identify the 'Underlying Story'.
    4. Provide a concrete business recommendation."""

    prompt = f"Data Summary: {state['data_summary']}\nPlots Created: {viz_meta}"
    response = llm.invoke([SystemMessage(content=system_msg), HumanMessage(content=prompt)])

    return {"final_report": response.content}


def router(state: AgentState):
    if state['error_log'] and state['retry_count'] < 3:
        return "coder"
    return "analyst"

workflow = StateGraph(AgentState)
workflow.add_node("profiler", profiler_node)
workflow.add_node("strategist", strategist_node)
workflow.add_node("coder", coder_node)
workflow.add_node("executor", executor_node)
workflow.add_node("analyst", analyst_node)

workflow.set_entry_point("profiler")
workflow.add_edge("profiler", "strategist")
workflow.add_edge("strategist", "coder")
workflow.add_edge("coder", "executor")

workflow.add_conditional_edges(
    "executor",
    router,
    {
        "coder": "coder",
        "analyst": "analyst"
    }
)

workflow.add_edge("analyst", END)


app = workflow.compile()

# %%
inputs = {"csv_path": "diabetes.csv"}
result = app.invoke(inputs)
# Out:
# <string>:90: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# <string>:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# <string>:83: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# <string>:94: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# <string>:104: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# <string>:114: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
print(result['final_report'])
# Out:
# ## 1️⃣ Kernel Density Estimate of BMI
# **Header:** *How is Body‑Mass‑Index (BMI) distributed across the cohort?*
#
# **What the plot shows**
# - A smooth, unimodal curve that peaks around **≈ 31 kg/m²** (the mode).
# - The left‑hand tail extends to **≈ 0**, reflecting implausibly low recorded BMIs (data‑entry errors or missing values coded as 0).
# - The right‑hand tail stretches out to **≈ 67 kg/m²**, indicating a small group of severely obese patients.
# - The distribution is **right‑skewed** (longer high‑BMI tail) rather than perfectly normal.
#
# **Underlying story**
# The majority of patients sit in the **overweight/obese range (BMI > 30)** – a known risk factor for type‑2 diabetes. The presence of many zeroes suggests a data‑quality issue that could bias any model that treats BMI as continuous.
#
# **Business recommendation**
# - **Clean the BMI column**: replace 0 values with `NaN` and consider imputation (e.g., median of similar age/sex groups) before model building.
# - **Target weight‑management programs** for the high‑BMI segment (BMI > 30) as they represent the bulk of the at‑risk population, promising higher ROI for preventive interventions.
#
# ---
#
# ## 2️⃣ Correlation Heatmap of All Numeric Features
# **Header:** *Which variables move together and which are most linked to diabetes?*
#
# **What the plot shows**
# - **Strong positive correlations**:
#   - **Glucose ↔ Outcome (≈ 0.47)** – the strongest link to diabetes.
#   - **BMI ↔ Outcome (≈ 0.31)** and **Age ↔ Outcome (≈ 0.27)** – moderate associations.
# - **Moderate inter‑feature correlations**:
#   - **Glucose ↔ BMI (≈ 0.20)**, **Pregnancies ↔ Age (≈ 0.20)**.
# - **Weak or negligible links**: Insulin, BloodPressure, SkinThickness, and DiabetesPedigreeFunction show correlations < 0.15 with Outcome.
# - No pair exceeds **0.8**, so multicollinearity is not a major concern.
#
# **Underlying story**
# High blood **glucose** levels are the clearest predictor of a diabetic label, while **BMI** and **age** provide supporting signals. Traditional clinical markers like **insulin** or **blood pressure** add little incremental predictive power in this dataset.
#
# **Business recommendation**
# - **Prioritize glucose screening** in any risk‑assessment tool; it yields the biggest lift in detection accuracy.
# - **Add BMI and age as secondary filters** to refine risk tiers.
# - **De‑emphasize insulin, blood pressure, and skin‑fold measurements** in low‑cost screening kits – they increase complexity without improving predictive performance.
#
# ---
#
# ## 3️⃣ Glucose vs. BMI Colored by Diabetes Outcome
# **Header:** *Do glucose and BMI together separate diabetics from non‑diabetics?*
#
# **What the plot shows**
# - **Diabetic points (Outcome = 1)** cluster in the **upper‑right quadrant** (high glucose > 130 mg/dL *and* high BMI > 30).
# - **Non‑diabetic points** dominate the **lower‑left** (glucose < 120 mg/dL, BMI < 30) but are scattered across the middle, showing overlap.
# - A **clear decision boundary** appears around **Glucose ≈ 125 mg/dL**; above this, the probability of diabetes spikes dramatically, especially when BMI is also elevated.
#
# **Underlying story**
# Both **hyperglycemia** and **obesity** act synergistically: patients who are both overweight and have elevated glucose are far more likely to be diabetic. However, a non‑trivial number of high‑glucose, low‑BMI patients are also diabetic, indicating that BMI alone cannot fully explain risk.
#
# **Business recommendation**
# - **Design a two‑stage triage**: first screen glucose; if > 125 mg/dL, then check BMI to prioritize high‑risk individuals for intensive follow‑up.
# - **Offer tailored lifestyle coaching**: for high‑glucose & high‑BMI patients, combine dietary counseling with weight‑loss programs; for high‑glucose but normal BMI, focus on carbohydrate management and medical monitoring.
#
# ---
#
# ## 4️⃣ Age vs. Diabetes Pedigree Function
# **Header:** *Is genetic risk (Pedigree) linked to age?*
#
# **What the plot shows**
# - Points are **widely scattered** with **no discernible trend**; the cloud is roughly rectangular.
# - **Correlation coefficient** (from the heatmap) is low (**≈ 0.12**), confirming a weak relationship.
# - Both young (≈ 21 y) and older (≈ 80 y) patients exhibit the full range of Pedigree values (0.08 – 2.4).
#
# **Underlying story**
# **Genetic predisposition** (Pedigree) appears **independent of age** in this cohort. Older patients are not necessarily more genetically at risk; age‑related risk likely stems from cumulative lifestyle and physiological changes rather than inherited factors.
#
# **Business recommendation**
# - **Treat Pedigree as a supplemental, not primary, risk factor**; allocate resources to age‑based screening programs rather than family‑history‑only initiatives.
# - **Integrate Pedigree scores** into a **personalized risk calculator** that weights them modestly, ensuring they enhance rather than dominate the prediction.
#
# ---
#
# ## 5️⃣ Average Diabetes Prevalence by Number of Pregnancies
# **Header:** *Does a higher pregnancy count signal greater diabetes risk?*
#
# **What the plot shows**
# - **Prevalence rises** from **≈ 10 %** at 0–1 pregnancies to a **peak of ≈ 35 %** around **6–8 pregnancies**.
# - After **≈ 8 pregnancies**, the line **flattens or slightly declines**, but sample sizes become very small (few women with > 10 pregnancies).
# - The trend is **monotonic up to the mid‑range**, suggesting a dose‑response relationship.
#
# **Underlying story**
# Repeated pregnancies may **expose women to cumulative insulin resistance**, increasing the chance of later‑life diabetes. The plateau at very high counts likely reflects **selection bias** (few observations) rather than a true protective effect.
#
# **Business recommendation**
# - **Create a women‑focused diabetes risk program** targeting those with **≥ 3 pregnancies** (or a history of gestational diabetes).
# - **Offer postpartum glucose tolerance testing** and **lifestyle workshops** for this subgroup, as early detection can prevent progression to type‑2 diabetes.
#
# ---
#
# ## 6️⃣ Class Distribution of Diabetes Outcome
# **Header:** *How imbalanced is the dataset?*
#
# **What the plot shows**
# - **≈ 65 %** of records are **non‑diabetic (Outcome = 0)**, **≈ 35 %** are **diabetic (Outcome = 1)**.
# - The imbalance is moderate (roughly a 2:1 ratio), not extreme but enough to bias naïve classifiers toward the majority class.
#
# **Underlying story**
# A **baseline “always predict non‑diabetic” model would achieve 65 % accuracy**, masking the real need to detect the 35 % who are diabetic. Model evaluation must therefore use **balanced metrics** (precision, recall, F1, ROC‑AUC) rather than raw accuracy.
#
# **Business recommendation**
# - **Apply class‑balancing techniques** (e.g., SMOTE, class‑weighting) when training predictive models.
# - **Set performance targets** that prioritize **recall (sensitivity)** for the diabetic class to avoid missing high‑risk patients, even at the cost of a modest increase in false positives.
#
# ---
#
# ## 7️⃣ Insulin Levels by Diabetes Outcome
# **Header:** *Do insulin measurements differ between diabetics and non‑diabetics?*
#
# **What the plot shows**
# - **Median insulin** for **non‑diabetics** ≈ 80 µU/mL, with an inter‑quartile range (IQR) of **≈ 30–120**.
# - **Diabetics** display a **higher median** ≈ 150 µU/mL and a **much wider IQR** (≈ 50–250), plus many extreme outliers up to **≈ 800**.
# - The **distribution is right‑skewed** for diabetics, reflecting **hyperinsulinemia** in early insulin‑resistant stages.
#
# **Underlying story**
# While **insulin is elevated on average in diabetics**, the **overlap with non‑diabetics is substantial**. This makes insulin a **noisy predictor** when used alone, but it may add value when combined with glucose and BMI.
#
# **Business recommendation**
# - **Incorporate insulin as a secondary feature** in risk models, but **do not rely on it for primary screening**.
# - **Consider cost‑benefit**: insulin assays are pricier than glucose; reserve them for **confirmatory testing** after an initial high‑glucose flag.
#
# ---
#
# ## 8️⃣ Blood Pressure Distribution by Diabetes Outcome
# **Header:** *Is blood pressure a discriminating factor for diabetes?*
#
# **What the plot shows**
# - Both outcome groups share a **similar central tendency** (~ 70 mm Hg) and comparable spread.
# - **Diabetic distribution** shows a **slightly heavier right tail**, with a few patients reaching **> 130 mm Hg**, but the difference is modest.
# - **Overlap is extensive**; the two density curves are almost superimposed.
#
# **Underlying story**
# **Blood pressure alone provides little discriminatory power** for diabetes status in this dataset. Hypertension may co‑occur with diabetes, but it is **not a strong early indicator**.
#
# **Business recommendation**
# - **De‑prioritize blood pressure in a rapid diabetes‑risk screen**; allocate resources to stronger predictors (glucose, BMI, age).
# - **Maintain BP monitoring** for overall cardiovascular health, but **bundle it with separate hypertension‑management pathways** rather than using it to flag diabetes risk.
#
# ---
#
# ### TL;DR Business Playbook
# | Insight | Action |
# |---|---|
# | Glucose is the top predictor | Build screening tools around fasting glucose > 125 mg/dL |
# | BMI adds a strong secondary signal | Pair glucose with BMI for risk tiering |
# | Pregnancy count matters for women | Offer targeted postpartum follow‑up for ≥ 3 pregnancies |
# | Data quality issues (BMI = 0, extreme insulin) | Clean/ impute before modeling |
# | Moderate class imbalance | Use balanced metrics & class‑weighting |
# | Insulin & BP are weak alone | Reserve insulin for confirmatory testing; treat BP as a separate cardio risk flag |
#
# Implementing these data‑driven steps will sharpen your diabetes‑risk identification, improve resource allocation, and ultimately boost preventive‑care ROI. 🚀
